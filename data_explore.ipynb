# %%
import dataretrieval.nwis as nwis
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Set parameters

# %%
inflow_perc = 0.16

# %% [markdown]
# ### Import data

# %%
nwis_site = '12340500'
q = nwis.get_record(sites=nwis_site, service='dv', start='2000-12-31', end='2023-12-6')['00060_Mean']
gw = pd.read_table('data/swldabyid660555134.txt', index_col='date')[:-2]

# %%
gw['daily_average'].plot()
plt.gca().invert_yaxis()

# %%
q.plot()
# Out:
# <Axes: xlabel='datetime'>

# %%
inflow = q*inflow_perc

# %%
inflow
# Out:
# datetime
# 2000-12-31 00:00:00+00:00    168.0
# 2001-01-01 00:00:00+00:00    168.0
# 2001-01-02 00:00:00+00:00    168.0
# 2001-01-03 00:00:00+00:00    163.2
# 2001-01-04 00:00:00+00:00    161.6
#                              ...
# 2023-12-02 00:00:00+00:00    228.8
# 2023-12-03 00:00:00+00:00    224.0
# 2023-12-04 00:00:00+00:00    228.8
# 2023-12-05 00:00:00+00:00    235.2
# 2023-12-06 00:00:00+00:00    236.8
# Name: 00060_Mean, Length: 8375, dtype: float64
